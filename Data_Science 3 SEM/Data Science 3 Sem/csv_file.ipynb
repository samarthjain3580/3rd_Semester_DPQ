# %%
import pandas as pd

# %%
df = pd.read_csv("SWS_07_start file.csv")
df.head()
# Out:
#   show_id     type Show_id                             title         director  \
# 0      s1    Movie       1              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show       3                         Ganglands  Julien Leclercq
# 2      s6  TV Show       6                     Midnight Mass    Mike Flanagan
# 3     s14    Movie      14  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie       8                           Sankofa     Haile Gerima
#
#          country date_added release_year rating  duration  \
# 0  United States  25/9/2021         2020  PG-13    90 min
# 1         France  24/9/2021         2021  TV-MA  1 Season
# 2  United States  24/9/2021         2021  TV-MA  1 Season
# 3         Brazil  22/9/2021         2021  TV-PG    91 min
# 4  United States  24/9/2021         1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# ...

# %%
df.tail()
# Out:
#      show_id     type Show_id               title director        country  \
# 8786   s8797  TV Show    8797          Yunus Emre      NaN         Turkey
# 8787   s8798  TV Show    8798           Zak Storm      NaN  United States
# 8788   s8801  TV Show    8801  Zindagi Gulzar Hai      NaN       Pakistan
# 8789   s8784  TV Show    8784                Yoko      NaN       Pakistan
# 8790   s8786  TV Show    8786                 YOM      NaN       Pakistan
#
#       date_added release_year rating   duration  \
# 8786   17/1/2017         2016  TV-PG  2 Seasons
# 8787   13/9/2018         2016  TV-Y7  3 Seasons
# 8788  15/12/2016         2012  TV-PG   1 Season
# 8789   23/6/2018         2016   TV-Y   1 Season
# 8790    7/6/2018         2016  TV-Y7   1 Season
#
#                                               listed_in
# 8786                   International TV Shows,TV Dramas
# 8787                                           Kids' TV
# 8788  International TV Shows,Romantic TV Shows,TV Dr...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8791 entries, 0 to 8790
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8791 non-null   object
#  1   type          8791 non-null   object
#  2   Show_id       8791 non-null   object
#  3   title         8791 non-null   object
#  4   director      6202 non-null   object
#  5   country       8503 non-null   object
#  6   date_added    8790 non-null   object
#  7   release_year  8790 non-null   object
#  8   rating        8790 non-null   object
#  9   duration      8789 non-null   object
#  10  listed_in     8789 non-null   object
# dtypes: object(11)
# memory usage: 755.6+ KB

# %%
df.describe()
# Out:
#        show_id   type Show_id  title       director        country date_added  \
# count     8791   8791    8791   8791           6202           8503       8790
# unique    8791      4    8791   8788           4527             86       1714
# top         s1  Movie       1  9-Feb  Rajiv Chilaka  United States   1/1/2020
# freq         1   6108       1      2             20           3239        110
#
#        release_year rating  duration                    listed_in
# count          8790   8790      8789                         8789
# unique           75     15       220                          513
# top            2018  TV-MA  1 Season  Dramas,International Movies
# freq           1146   3205      1791                          362

# %%
new_df = df.dropna()
new_df.head()
# Out:
#   show_id     type Show_id                             title         director  \
# 0      s1    Movie       1              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show       3                         Ganglands  Julien Leclercq
# 2      s6  TV Show       6                     Midnight Mass    Mike Flanagan
# 3     s14    Movie      14  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie       8                           Sankofa     Haile Gerima
#
#          country date_added release_year rating  duration  \
# 0  United States  25/9/2021         2020  PG-13    90 min
# 1         France  24/9/2021         2021  TV-MA  1 Season
# 2  United States  24/9/2021         2021  TV-MA  1 Season
# 3         Brazil  22/9/2021         2021  TV-PG    91 min
# 4  United States  24/9/2021         1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# ...

# %%
new = df.dropna(inplace=True)
